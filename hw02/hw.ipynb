# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

print("download dataset")
df = pd.read_csv('IoT_Failure_Prediction_Dataset.csv')
# Out:
# download dataset
